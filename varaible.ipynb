# %% [markdown]
# # VARAIBLES
# Varaibles temporarily store data in a computer memory. so in python we start with the name of the varaibles then an equal sign then a value

# %%
#price is refers here as an integer which is  a primitive data types 
price=10
#here we are trying to update the value of 20 
price=20
double=2444.8
print(price)
print(double)
#boolean store only True or False and always put the bigining in capital letter 
is_rainning=True
# Out:
# 20
# 2444.8

# %% [markdown]
# ##### exercise
# we check in a patient named john smith He's 20 years old and is a new patient.Try and identify variables in that text
# and tell if it is an existing or a new patients
#
# answer:
# - name=john smith`
# - age=20
# - is_patient_new=True

# %% [markdown]
# # USER INPUT
# user input used a particular built in function in python called **input()** this built in functions enables to store what the user types and print it to the terminal for the user himself to see what he has type. it main functions is to store what the user type in a container which is called a varaibles

# %%
# Ask the user for their name
name = input("Enter your name: ")

# Print a greeting
print("Hello, " + name + "!")
# Out:
# Hello, junior!

# %%
#Ask two questions:person's name and fauvaurite color then print a message likes "mosh likes blue"
name=input("enter your name:")
fauvaurite_color=input(" enter your fauvaurite color:")
print(f"{name} likes {fauvaurite_color}")
# Out:
# pamsy likes blue

# %%
present_year=int(input("enter the year you where born:"))
year_born=int(input("enter your age "))
result=year_born-present_year
print(f"this is your age {result}")
# Out:
# this is your age 21

# %% [markdown]
# # type conversion
# We cannot combine a string with an integer directly. If we do, for example, without converting present_year to an integer, we could get an error in the code. Therefore, we need to specify which data types we want to use.
