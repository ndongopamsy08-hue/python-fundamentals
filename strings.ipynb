# %% [markdown]
# # Strings
# Strings are just a combination of characters. As seen below, we can start a string with an apostrophe (') or with double quotes (").

# %%
course='python"s course'
courses="python's course"
cours='''hello pamsy you  have started leraning jupyter good for futures projects and in the your goal to be a good network engenner '''
print(course)
print(courses)
print(cours)
#acessing a Strings so start at index one and stop at the index from the left 
print(course[1:-2])
# Out:
# python"s course
# python's course
# hello pamsy you  have started leraning jupyter good for futures projects and in the your goal to be a good network engenner
# ython"s cour
